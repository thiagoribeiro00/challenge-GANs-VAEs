# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagoribeiro00/Ltrace/blob/main/Gans1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision -q

# %%
import h5py
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import torchvision.utils as vutils
import os


# Carregar o arquivo HDF5
file_path = '/content/drive/MyDrive/train_images.h5'
with h5py.File(file_path, 'r') as f:
    dataset_name = list(f.keys())[0]
    images = np.array(f[dataset_name])

# Redimensionar e converter as imagens para escala de cinza
images_resized = []
for img in images:
    resized_img = cv2.resize(img, (64, 64))  # Redimensionar para 64x64
    if resized_img.ndim == 3:  # Se a imagem tiver 3 canais
        resized_img = cv2.cvtColor(resized_img, cv2.COLOR_RGB2GRAY)  # Converter para escala de cinza
    # Normalizar a imagem para o intervalo [-1, 1]
    resized_img = (resized_img / 255.0) * 2 - 1
    images_resized.append(resized_img)

# Converter as imagens para tensor e adicionar dimensão de canal
images_tensor = torch.tensor(np.array(images_resized), dtype=torch.float32).unsqueeze(1)

# Criar um DataLoader
batch_size = 64
dataset = TensorDataset(images_tensor)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Detectar dispositivo (GPU ou CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Função de inicialização de pesos (Xavier)
def weights_init(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.zeros_(m.bias)

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(100, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Linear(512, 1 * 64 * 64),
            nn.Tanh()
        )

    def forward(self, z):
        return self.model(z).view(-1, 1, 64, 64)

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(0.2),
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(0.2),
            nn.Flatten(),
            nn.Linear(32 * 16 * 16, 1)
        )

    def forward(self, x):
        return torch.sigmoid(self.model(x))

# Função para calcular o gradient penalty
def gradient_penalty(discriminator, real_data, fake_data, lambda_gp=10):
    batch_size = real_data.size(0)
    epsilon = torch.rand(batch_size, 1, 1, 1, device=real_data.device)
    interpolated = epsilon * real_data + (1 - epsilon) * fake_data
    interpolated.requires_grad_(True)

    d_interpolated = discriminator(interpolated)
    gradients = torch.autograd.grad(outputs=d_interpolated,
                                    inputs=interpolated,
                                    grad_outputs=torch.ones_like(d_interpolated),
                                    create_graph=True,
                                    only_inputs=True)[0]

    grad_norm = gradients.view(batch_size, -1).norm(2, dim=1).mean()
    gp = (grad_norm - 1) ** 2
    return lambda_gp * gp

# Configurações
latent_dim = 100
num_epochs = 100
learning_rate = 0.0003
beta1 = 0.5

# Inicializando os modelos, otimizadores e funções de perda
generator = Generator().to(device)
discriminator = Discriminator().to(device)
generator.apply(weights_init)
discriminator.apply(weights_init)

optimizer_G = optim.Adam(generator.parameters(), lr=learning_rate, betas=(beta1, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=learning_rate, betas=(beta1, 0.999))

criterion = nn.BCELoss()
lambda_gp = 10  # Coeficiente do gradient penalty

# Função para salvar imagens geradas
def save_generated_images(epoch, fixed_noise):
    # Criar o diretório se não existir
    os.makedirs('images', exist_ok=True)

    with torch.no_grad():
        fake_images = generator(fixed_noise).detach().cpu()
        vutils.save_image(fake_images, f'images/epoch_{epoch}.png', normalize=True)
# Inicializando o ruído fixo para visualização
fixed_noise = torch.randn(batch_size, latent_dim, device=device)

# Loop de treinamento
d_losses = []
g_losses = []

for epoch in range(num_epochs):
    for i, (real_images,) in enumerate(dataloader):
        real_images = real_images.to(device)
        real_labels = torch.ones(real_images.size(0), 1, device=device)
        fake_labels = torch.zeros(real_images.size(0), 1, device=device)

        # Atualizar o discriminador
        optimizer_D.zero_grad()
        outputs = discriminator(real_images)
        d_loss_real = criterion(outputs, real_labels)

        z = torch.randn(real_images.size(0), latent_dim, device=device)
        fake_images = generator(z)
        outputs = discriminator(fake_images.detach())
        d_loss_fake = criterion(outputs, fake_labels)

        gp = gradient_penalty(discriminator, real_images, fake_images)
        d_loss = d_loss_real + d_loss_fake + gp
        d_loss.backward(retain_graph=True)  # Adicione retain_graph=True aqui
        optimizer_D.step()

        # Atualizar o gerador
        optimizer_G.zero_grad()
        outputs = discriminator(fake_images)
        g_loss = criterion(outputs, real_labels)
        g_loss.backward()  # Aqui, você não precisa de retain_graph=True
        optimizer_G.step()

    # Armazenar e exibir perdas
    d_losses.append(d_loss.item())
    g_losses.append(g_loss.item())

    print(f'Época [{epoch + 1}/{num_epochs}], Perda D: {d_loss.item():.4f}, Perda G: {g_loss.item():.4f}')
    if (epoch + 1) % 10 == 0:
        save_generated_images(epoch + 1, fixed_noise)
        plt.figure(figsize=(10, 5))
        plt.plot(d_losses, label='Perda Discriminador')
        plt.plot(g_losses, label='Perda Gerador')
        plt.xlabel('Época')
        plt.ylabel('Perda')
        plt.legend()
        plt.show()
# Out:
# Época [1/100], Perda D: 2.0715, Perda G: 1.1111
# Época [2/100], Perda D: 1.5044, Perda G: 0.7168
# Época [3/100], Perda D: 1.4520, Perda G: 0.6380
# Época [4/100], Perda D: 1.8523, Perda G: 0.5397
# Época [5/100], Perda D: 1.4537, Perda G: 0.7673
# Época [6/100], Perda D: 1.6054, Perda G: 0.6276
# Época [7/100], Perda D: 1.5216, Perda G: 0.6522
# Época [8/100], Perda D: 1.5247, Perda G: 0.6381
# Época [9/100], Perda D: 1.4371, Perda G: 0.6611
# Época [10/100], Perda D: 1.9888, Perda G: 0.4913
# Época [11/100], Perda D: 1.7887, Perda G: 0.6111
# Época [12/100], Perda D: 1.4715, Perda G: 0.6444
# Época [13/100], Perda D: 1.4179, Perda G: 0.6856
# Época [14/100], Perda D: 1.4941, Perda G: 0.5811
# Época [15/100], Perda D: 1.4513, Perda G: 0.6580
# Época [16/100], Perda D: 1.5161, Perda G: 0.6956
# Época [17/100], Perda D: 1.4175, Perda G: 0.6650
# Época [18/100], Perda D: 1.4920, Perda G: 0.6500
# Época [19/100], Perda D: 1.4281, Perda G: 0.8009
# Época [20/100], Perda D: 1.5035, Perda G: 0.6314
# Época [21/100], Perda D: 1.6812, Perda G: 0.5104
# Época [22/100], Perda D: 1.4457, Perda G: 0.6585
# Época [23/100], Perda D: 1.4293, Perda G: 0.7596
# Época [24/100], Perda D: 1.4899, Perda G: 0.6374
# Época [25/100], Perda D: 1.4569, Perda G: 0.6691
# Época [26/100], Perda D: 1.4805, Perda G: 0.6507
# Época [27/100], Perda D: 1.4809, Perda G: 0.5839
# Época [28/100], Perda D: 1.4012, Perda G: 0.6954
# Época [29/100], Perda D: 1.4160, Perda G: 0.6736
# Época [30/100], Perda D: 1.4468, Perda G: 0.6864
# Época [31/100], Perda D: 1.4438, Perda G: 0.7205
# Época [32/100], Perda D: 1.4338, Perda G: 0.6555
# Época [33/100], Perda D: 1.4459, Perda G: 0.6498
# Época [34/100], Perda D: 1.4242, Perda G: 0.7875
# Época [35/100], Perda D: 1.4218, Perda G: 0.6802
# Época [36/100], Perda D: 1.4421, Perda G: 0.6261
# Época [37/100], Perda D: 1.4134, Perda G: 0.6765
# Época [38/100], Perda D: 1.5072, Perda G: 0.6771
# Época [39/100], Perda D: 1.4402, Perda G: 0.6788
# Época [40/100], Perda D: 1.4346, Perda G: 0.6685
# Época [41/100], Perda D: 1.4362, Perda G: 0.6841
# Época [42/100], Perda D: 1.4254, Perda G: 0.6745
# Época [43/100], Perda D: 1.4225, Perda G: 0.6768
# Época [44/100], Perda D: 1.3956, Perda G: 0.6571
# Época [45/100], Perda D: 1.4050, Perda G: 0.6417
# Época [46/100], Perda D: 1.4222, Perda G: 0.6292
# Época [47/100], Perda D: 1.4015, Perda G: 0.7061
# Época [48/100], Perda D: 1.4413, Perda G: 0.6672
# Época [49/100], Perda D: 1.4174, Perda G: 0.6800
# Época [50/100], Perda D: 1.4110, Perda G: 0.6895
# Época [51/100], Perda D: 1.4087, Perda G: 0.6792
# Época [52/100], Perda D: 1.4250, Perda G: 0.6464
# Época [53/100], Perda D: 1.4015, Perda G: 0.6746
# Época [54/100], Perda D: 1.4055, Perda G: 0.6996
# Época [55/100], Perda D: 1.4064, Perda G: 0.6847
# Época [56/100], Perda D: 1.4130, Perda G: 0.6695
# Época [57/100], Perda D: 1.4171, Perda G: 0.6651
# Época [58/100], Perda D: 1.4733, Perda G: 0.5122
# Época [59/100], Perda D: 1.3971, Perda G: 0.6887
# Época [60/100], Perda D: 1.2214, Perda G: 0.8660
# Época [61/100], Perda D: 1.3869, Perda G: 0.6951
# Época [62/100], Perda D: 1.4415, Perda G: 0.6989
# Época [63/100], Perda D: 1.5053, Perda G: 0.6880
# Época [64/100], Perda D: 1.3843, Perda G: 0.6973
# Época [65/100], Perda D: 1.3931, Perda G: 0.6878
# Época [66/100], Perda D: 1.3908, Perda G: 0.6806
# Época [67/100], Perda D: 1.3871, Perda G: 0.6907
# Época [68/100], Perda D: 1.3876, Perda G: 0.6938
# Época [69/100], Perda D: 1.3860, Perda G: 0.6939
# Época [70/100], Perda D: 1.3885, Perda G: 0.6957
# Época [71/100], Perda D: 1.3825, Perda G: 0.7138
# Época [72/100], Perda D: 1.3748, Perda G: 0.6975
# Época [73/100], Perda D: 1.3709, Perda G: 0.7012
# Época [74/100], Perda D: 1.4009, Perda G: 0.6913
# Época [75/100], Perda D: 1.3947, Perda G: 0.7016
# Época [76/100], Perda D: 1.3962, Perda G: 0.7257
# Época [77/100], Perda D: 1.3942, Perda G: 0.6826
# Época [78/100], Perda D: 1.3926, Perda G: 0.7258
# Época [79/100], Perda D: 1.3867, Perda G: 0.6930
# Época [80/100], Perda D: 1.3779, Perda G: 0.6970
# Época [81/100], Perda D: 1.3810, Perda G: 0.7030
# Época [82/100], Perda D: 1.2748, Perda G: 0.7843
# Época [83/100], Perda D: 1.3715, Perda G: 0.7001
# Época [84/100], Perda D: 1.3111, Perda G: 0.7439
# Época [85/100], Perda D: 1.3719, Perda G: 0.7088
# Época [86/100], Perda D: 1.3590, Perda G: 0.7074
# Época [87/100], Perda D: 1.3671, Perda G: 0.7046
# Época [88/100], Perda D: 1.3728, Perda G: 0.7015
# Época [89/100], Perda D: 1.3666, Perda G: 0.7035
# Época [90/100], Perda D: 1.3547, Perda G: 0.7308
# Época [91/100], Perda D: 1.4102, Perda G: 0.6968
# Época [92/100], Perda D: 1.3691, Perda G: 0.6958
# Época [93/100], Perda D: 1.3718, Perda G: 0.7202
# Época [94/100], Perda D: 1.3598, Perda G: 0.7040
# Época [95/100], Perda D: 1.3494, Perda G: 0.7378
# Época [96/100], Perda D: 1.3621, Perda G: 0.7035
# Época [97/100], Perda D: 1.3574, Perda G: 0.7088
# Época [98/100], Perda D: 1.3584, Perda G: 0.7087
# Época [99/100], Perda D: 1.3576, Perda G: 0.7091
# Época [100/100], Perda D: 1.3746, Perda G: 0.7114

# %%
import matplotlib.pyplot as plt
import numpy as np

# Função para exibir imagens geradas
def show_generated_images(epoch, fixed_noise):
    with torch.no_grad():
        fake_images = generator(fixed_noise).detach().cpu()

    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(np.transpose(vutils.make_grid(fake_images[:64], padding=2, normalize=True), (1, 2, 0)))
    plt.title(f"Epoch {epoch}")
    plt.show()

# Inicializando o ruído fixo para visualização
fixed_noise = torch.randn(64, latent_dim, device=device)

# Exibir as imagens geradas após o treinamento
show_generated_images(num_epochs, fixed_noise)
